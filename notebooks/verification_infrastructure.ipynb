# %%
import mlflow

mlflow.set_tracking_uri("http://localhost:5000")
mlflow.set_experiment("verification infracstructure C73")

with mlflow.start_run(run_name="connection-postgres-minio"):
    mlflow.log_param("objectif", "verification infrastructure")
    mlflow.log_text(
        "Connexion MLflow et MinIO fonctionnelle. Aucun modele entraine.",
        "verification.txt",
    )
print("Run et fichier enregistrers.")
# Out:
# 2026/09/20 16:15:52 INFO mlflow.tracking.fluent: Experiment with name 'verification infracstructure C73' does not exist. Creating a new experiment.
# 🏃 View run connection-postgres-minio at: http://localhost:5000/#/experiments/1/runs/589debcee7904c2a9b2250b5158e8d88
# 🧪 View experiment at: http://localhost:5000/#/experiments/1
# Run et fichier enregistrers.
